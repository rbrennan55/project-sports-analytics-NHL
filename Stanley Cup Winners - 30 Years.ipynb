# %%
import pandas as pd
import datetime
from random import randint
from time import sleep
import os

# %%
# Get game dates of games played

url = "https://en.wikipedia.org/wiki/List_of_Stanley_Cup_champions"

stanleycup_champs = pd.read_html(url)

stanleycup_byyear_df = stanleycup_champs[2]
stanleycup_byyear_df.head()
# Out:
#    Year                     Winning team                   Coach Games  \
# 0  1927     Ottawa Senators (C) (5, 4–1)               Dave Gill   2–0
# 1  1928    New York Rangers (A) (1, 1–0)  Lester Patrick-playing   3–2
# 2  1929       Boston Bruins (A) (2, 1–1)                Art Ross   2–0
# 3  1930  Montreal Canadiens (C) (6, 3–2)              Cecil Hart   2–0
# 4  1931  Montreal Canadiens (C) (7, 4–2)              Cecil Hart   3–2
#
#                         Losing team         Coach.1  \
# 0        Boston Bruins (A) (1, 0–1)        Art Ross
# 1     Montreal Maroons (C) (2, 1–1)    Eddie Gerard
# 2     New York Rangers (A) (2, 1–1)  Lester Patrick
# 3        Boston Bruins (A) (3, 1–2)        Art Ross
# 4  Chicago Black Hawks (A) (1, 0–1)      Dick Irvin
#
#                    Winning goal
# 0     Cy Denneny (7:30, second)
# 1   Frank Boucher (3:35, third)
# 2    Bill Carson (18:02, third)
# 3   Howie Morenz (1:00, second)
# 4  Johnny Gagnon (9:59, second)

# %%
stanleycup_cleaned_df = stanleycup_byyear_df.loc[stanleycup_byyear_df['Year'].between(1991,2022)]
stanleycup_cleaned_df = stanleycup_cleaned_df[["Year", "Winning team", "Losing team"]]
stanleycup_cleaned_df["Winning team"] = stanleycup_cleaned_df["Winning team"].str.split('(').str[0]
stanleycup_cleaned_df["Losing team"] = stanleycup_cleaned_df["Losing team"].str.split('(').str[0]

stanleycup_cleaned_df.drop(stanleycup_cleaned_df[(stanleycup_cleaned_df['Year'] == 2005)].index, inplace=True)

stanleycup_cleaned_df
# Out:
#     Year          Winning team               Losing team
# 64  1991  Pittsburgh Penguins     Minnesota North Stars
# 65  1992  Pittsburgh Penguins        Chicago Blackhawks
# 66  1993   Montreal Canadiens         Los Angeles Kings
# 67  1994     New York Rangers         Vancouver Canucks
# 68  1995    New Jersey Devils         Detroit Red Wings
# 69  1996   Colorado Avalanche          Florida Panthers
# 70  1997    Detroit Red Wings       Philadelphia Flyers
# 71  1998    Detroit Red Wings       Washington Capitals
# 72  1999         Dallas Stars            Buffalo Sabres
# 73  2000    New Jersey Devils              Dallas Stars
# 74  2001   Colorado Avalanche         New Jersey Devils
# 75  2002    Detroit Red Wings       Carolina Hurricanes
# 76  2003    New Jersey Devils   Mighty Ducks of Anaheim
# 77  2004  Tampa Bay Lightning            Calgary Flames
# 79  2006  Carolina Hurricanes           Edmonton Oilers
# 80  2007        Anaheim Ducks           Ottawa Senators
# 81  2008    Detroit Red Wings       Pittsburgh Penguins
# 82  2009  Pittsburgh Penguins         Detroit Red Wings
# 83  2010   Chicago Blackhawks       Philadelphia Flyers
# 84  2011        Boston Bruins         Vancouver Canucks
# 85  2012    Los Angeles Kings         New Jersey Devils
# 86  2013   Chicago Blackhawks             Boston Bruins
# 87  2014    Los Angeles Kings          New York Rangers
# 88  2015   Chicago Blackhawks       Tampa Bay Lightning
# 89  2016  Pittsburgh Penguins           San Jose Sharks
# 90  2017  Pittsburgh Penguins       Nashville Predators
# 91  2018  Washington Capitals      Vegas Golden Knights
# 92  2019      St. Louis Blues             Boston Bruins
# 93  2020  Tampa Bay Lightning              Dallas Stars
# 94  2021  Tampa Bay Lightning        Montreal Canadiens
# 95  2022   Colorado Avalanche       Tampa Bay Lightning
